# %%
from MF_extractor import *

# %%
lhe_file = "/home/josecasa/Descargas/PP_Wp_BTauNu_M1.lhe.gz"
events = pylhe.to_awkward(pylhe.read_lhe_with_attributes(lhe_file))

# %%
print(f"Number of events: {pylhe.read_num_events(lhe_file)}")
# Out:
# Number of events: 100000

# %%
pt_hist(events,75,0,1500,-3,"\tau")
# Out:
# /home/josecasa/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# (Hist(Regular(75, 0, 1500, label='Axis 0'), storage=Int64()) # Sum: 99999.0 (100000.0 with flow),
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x75d8567c5300>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)])
# /usr/lib/python3/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
eta_hist(events,50,-5,5,-3,"\tau")
# Out:
# (Hist(Regular(50, -5, 5, label='Axis 0'), storage=Int64()) # Sum: 100000.0,
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x75d848dd3280>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)])
# /usr/lib/python3/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
phi_hist(events,63,0,6.3,-3,"\tau")
# Out:
# (Hist(Regular(63, 0, 6.3, label='Axis 0'), storage=Int64()) # Sum: 50042.0 (100000.0 with flow),
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x75d848d2e740>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)])
# /usr/lib/python3/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
minv_hist(events,100,0,2000,-3,-1,"\tau","b",mlog=False)
# Out:
# (Hist(Regular(100, 0, 2000, label='Axis 0'), storage=Int64()) # Sum: 99925.0 (100000.0 with flow),
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x75d8659c2440>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)])
# /usr/lib/python3/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
mT_nu_hist(events,100,0,2000,-3,-2,"\tau",mlog=False)
# Out:
# (Hist(Regular(100, 0, 2000, label='Axis 0'), storage=Int64()) # Sum: 100000.0,
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x75d849ac1540>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)])
# /usr/lib/python3/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
mTot_nu_hist(events,100,0,2000,-3,-1,-2,"\tau","b",mlog=False)
# Out:
# (Hist(Regular(100, 0, 2000, label='Axis 0'), storage=Int64()) # Sum: 99832.0 (100000.0 with flow),
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x75d84caf4580>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)])
# /usr/lib/python3/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
mT_MET_hist(events,100,0,2000,-3,-1,"\tau",mlog=False)
# Out:
# (Hist(Regular(100, 0, 2000, label='Axis 0'), storage=Int64()) # Sum: 99999.0 (100000.0 with flow),
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x75d84ca2db70>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)])
# /usr/lib/python3/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
mTot_MET_hist(events,100,0,2000,-3,-1,"\tau","b",mlog=False)
# Out:
# (Hist(Regular(100, 0, 2000, label='Axis 0'), storage=Int64()) # Sum: 99898.0 (100000.0 with flow),
#  [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x75d84b8a61d0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)])
# /usr/lib/python3/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
